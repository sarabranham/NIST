# %% [markdown]
# # Examples
# TwoPortModels documentation contains interactive examples in jupyter explaining the package and how to use it. <br/>
# This documentation was designed by Sara Branham (<a href="mailto:sara.m.branham@gmail.com">sara.m.branham@gmail.com</a>) 2017.
#
# <h2> Project Specific Examples</h2>
# Examples specific to the TwoPortModels and TPMComplex.
#
# <h3>Calculation Example </h3>
# <ul>
#     <li> <a href="./Guide to Calculations.ipynb">Guide to Calculations</a><br/>
#         An example of the different numerical calculation functions.
#     </li>
# </ul>
#
# <h3>Equation Example</h3>
# <ul>
#     <li> <a href="./Guide to Equations.ipynb">Guide to Equations</a><br/>
#         An example of the symbolic and numeric equations functions.
#     </li>
# </ul>
#
# <h3>Plotting Example</h3>
# <ul>
#     <li> <a href="./Guide to Plotting.ipynb">Guide to Plotting</a><br/>
#         An example of the different plotting functions.
#     </li>
# </ul>
#
#
# <h2> Library Examples </h2>
# Examples for using Sympy and Lmfit
#
# <h3> Lmfit </h3>
# <ul>
#     <li> <a href="./Lmfit_Practice.ipynb">Lmfit Practice</a><br/>
#         General methods and uses for Lmfit.
#     </li>
#
#     <li> <a href="./Lmfit_SParams.ipynb">Lmfit Applied</a><br/>
#         Specific uses for Lmfit within TPM.
#     </li>
# </ul>
#
# <h3> Sympy </h3>
# <ul>
#     <li> <a href="./Sympy1_Intro.ipynb"> Sympy Tutorial 1</a><br/>
#         Covers really general mathematical operations for sympy.
#     </li>
#
#     <li> <a href="./Sympy2_Errors.ipynb"> Sympy Tutorial 2</a><br/>
#         Common errors found while using sympy.
#     </li>
#
#     <li> <a href="./Sympy3_BasicOp.ipynb"> Sympy Tutorial 3</a><br/>
#         Basic operations.
#     </li>
#
#     <li> <a href="./Sympy4_Printing.ipynb"> Sympy Tutorial 4</a><br/>
#         Different methods for displaying functions.
#     </li>
#
#     <li> <a href="./Sympy5_Simplify.ipynb"> Sympy Tutorial 5</a><br/>
#         How simplification works and different ways to use it.
#     </li>
#
#     <li> <a href="./Sympy6_Calculus.ipynb"> Sympy Tutorial 6</a><br/>
#         Calculus applications.
#     </li>
#
#     <li> <a href="./Sympy7_Solvers.ipynb"> Sympy Tutorial 7</a><br/>
#         Different ways of solving equations (symbolic/numeric).
#     </li>
#
#     <li> <a href="./Sympy8_Matrices.ipynb"> Sympy Tutorial 8</a><br/>
#         Dealing with matrices.
#     </li>
#
#     <li> <a href="./Sympy_Lambdify.ipynb"> Sympy Lambdify</a><br/>
#         More in depth usage of lambdify.
#     </li>
#
#     <li> <a href="./Sympy_PlotsandRISep.ipynb"> Sympy Plotting and R/I Separation</a><br/>
#         Using sympy to plot and separate real and imaginary components.
#     </li>
#
#
# </ul>

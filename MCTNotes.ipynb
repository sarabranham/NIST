# %% [markdown]
# ﻿GENERAL:
# - everything can be found with A and B
# - ports = pairs of terminals where the current into one is equal to the current leaving the other (coax or waveguide)
# - reciprocity = an s matrix is equal to its transpose
# - lossless = no power is lost (Σa(n)^2 = Σb(n)^2)
# - S Param
#     - element that describes electrical behavior of linear electrical networks when undergoing steady state stimuli by electrical signals       - works well w/ high frequency, everything goes through power
#     - represents magnitude/angle (amplitude/phase), usually in complex polar coordinates
#     - CAN FIND: gain, return loss, voltage standing wave ratio (VSWR), reflection coefficient, amplifier stability
#     - MUST KNOW: frequency, characteristic impedance (prob 50Ω), # ports, and some other things (temp, length, etc)
#
#     ***************   s(11) = input voltage reflection coef.        s(12) = reverse voltage gain              ***************
#     ***************   s(21) = forward voltage gain                  s(22) = output voltage reflection coef.   ***************
#
# - SHORT = device w/ lower resistance than normal circuit (capacitor)
# - OPEN = break in the wire (i = 0, inductor)
# - LOAD = some amount of power in consumed (resistor, 50Ω)
# - THRU = starts and ends in the same place?
#
#
# 2 PORT:
# - b always goes away from device, a always goes toward
# - S/R/T are different variables representing scattering parameters for different systems (ex: R = cascading 2 port)
# - attenuation is the change in power after a 2 port is placed between the generator and load in a matched system
#     = -10log(p(f)/p(i)) OR -20log10(s(21))
# - efficiency can be broken into general efficiency or the efficieny between two points (etc)
#     p(out)/p(in) = b(2)^2 * (1 - |Γ(l)|^2)
#     η = [s(21)^2 * (1 - |Γ(l)|^2)] / [((1 - s(22)Γ(l))^2 - (s(12)s(21) - s(11)s(22)*Γ(l) + s(11))^2]
#         simplifies to |A - BC| / (1 - C^2)
#
# EQNS:
# - voltage and current
# 	V = A + B and I = (A-B)/Z.
#         	where z. = z @ t = 0
# 	A = 1/2(V + IZ.) and B = 1/2(V - IZ.)
#
#
# - transverse components of e/m fields
# 	E(t) = [ Ce^(j(ωt - βz)) + De^(j(ωt + βz)) ] * F(t)                  >>>   [C + D] * F(t)
# 	H(t) = [ Ce^(j(ωt - βz)) - De^(j(ωt + βz)) ] * Y * k x F(t)          >>>   [C - D] * Y * k x F(t)
#
# 		where
# 		c/d = complex constants                         F(t) = perp to k, how E(t) varies over cross section
# 		k = unit vector in z (axis of transmission)     k x F = rotate F in transverse plane (so H perp E)
# 		Y = function of dielectric/mag props.           time dependence = e^jωt and z dep. = e^±jβz
#
# - velocity of wave
# 	v = Δz/Δt = ω/β
#     β = 2πf/v = 2π/λ
#
#
# - power normalization (derivation makes no sense)
# 	P = K(|A|^2 - |B|^2)
# 	if low frequency
# 		P = (|A|^2 - |B|^2) / Z.
#
#
# - boundary condition
# 	E = [ Ae^(j(ωt - βz)) + Be^(j(ωt + βz)) ]
#
# 	if a = b (standing wave, min bz + θ = nπ, max bz + θ = (2n+1)π/2
# 	E = [ ae^(-jβz) + ce^(jβz) ]           >>>>> MATH IT >>>>>          E = 2ae^(jθ)cos(βz + θ)
#
#
# - reflection
# 	a = bΓ
# 		where
#         a = incidence amplitude, b = emerging amplitude, gamma = reflection coefficient
#
# 	p(abs) = |b^2| - |a^2|
# 	OR p(abs) = |b^2|(1 - |Γ|^2)
#
# 	gamma = 0 either means totally absorbed by termination or something else went wrong
# 	gamma = 1 means totally reflected, negative numbers depending on where you define 0
# 	b is actually an infinite series but these are linear models so :/
#
#
# - power transfer w/ generator
# 	P = [ |b(g)|^2 / (1 - |Γ(g)|^2) ] * [ ((1 - |Γ(g)|^2)*(1 - |Γ(l)|^2)) / |1 - Γ(g)Γ(l)|^2 ]
#
# 	simplify second term - new var.
# 		M(gl) = 1 - [ |Γ(l) - Γ(g)|^2 / |1 - Γ(g)Γ(l)|^2 ]
#
# 	therefore
# 		P = P(g)M(gl)
#
#
#
# - **** multi port systems ****
#
# 	b(1) = S(11)a(1) + S(12)a(2)   and    b(2) = S(21)a(1) + S(22)a(2)
# 	where s = scatter and a/b are wave freqs?
#
# 	b(1) = s(11)  s(12) * a(1)
# 	b(2)   s(21)  s(22)   a(2)
#
# 	a = 1/2(v + Z.i) and b = 1/2(v - Z.i)
# 		where Z. = diagonal matrix w/ characteristic impedances
#
#
#
# QUESTIONS:
#
# - Q1: What's the range of uncertainties/where do they come from?
# - Q2: Complex coefficient means to add e^jBz?
# - Q3: What parameters are known vs. calculated?
# - Q6: On most recent page of notes what is R?
# - Q7: Conjugate transpose??
